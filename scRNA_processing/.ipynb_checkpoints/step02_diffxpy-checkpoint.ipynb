# %%
import diffxpy.api as de
# Out:
# 2025-05-06 22:23:25.395892: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-06 22:23:25.444544: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-06 22:23:25.856602: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-06 22:23:25.859316: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
import diffxpy
print(diffxpy.__version__)
# Out:
# v0.7.4+21.g12f1286.dirty

# %%
import scanpy as sc
#from cellbender.remove_background.downstream import anndata_from_h5
import pandas as pd
import numpy as np
import scipy.sparse
import scipy.cluster.hierarchy as shc
from scipy import stats
import matplotlib.pyplot as plt
import matplotlib
from scipy.sparse import csr_matrix, hstack

# %%
adata = sc.read_h5ad('../intermediate_outputs/sc_data/strict_epdsc_annotated_data.h5')

# %%
adata_d30 = adata[adata.obs['Time'] == 'D30']
adata_y1 = adata[adata.obs['Time'] == 'Y1']

# %%
formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata_d30.copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['DB_early_proliferation', 'DB_intermediate', 'DB_stress', 'DB_advanced']) ) ]

adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Condition'] == 'PIMQ']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_PIMQ_vs_Control_DB_timepoint_D30.csv')


formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata_y1.copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['DB_early_proliferation', 'DB_intermediate', 'DB_stress', 'DB_advanced']) ) ]

adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Condition'] == 'PIMQ']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_PIMQ_vs_Control_DB_timepoint_Y1.csv')

formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata_d30.copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['UB_proliferation', 'UB_structure', 'UB_stem_like', 'UB_classic']) ) ]

adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Condition'] == 'PIMQ']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_PIMQ_vs_Control_UB_timepoint_D30.csv')


formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata_y1.copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['UB_proliferation', 'UB_structure', 'UB_stem_like', 'UB_classic']) ) ]

adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Condition'] == 'PIMQ']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_PIMQ_vs_Control_UB_timepoint_Y1.csv')
# Out:
# training location model: False
# training scale model: True
# iter   0: ll=1638376950.051371
# iter   1: ll=1638376950.051371, converged: 0.00% (loc: 100.00%, scale update: False), in 0.00sec
# iter   2: ll=14267425.080733, converged: 0.00% (loc: 0.00%, scale update: True), in 50.67sec
# iter   3: ll=14267425.080733, converged: 0.00% (loc: 100.00%, scale update: False), in 0.00sec
# iter   4: ll=11804285.930618, converged: 45.38% (loc: 45.38%, scale update: True), in 45.14sec
# iter   5: ll=11804285.930618, converged: 45.38% (loc: 100.00%, scale update: False), in 0.00sec
# iter   6: ll=11099399.595625, converged: 83.18% (loc: 83.18%, scale update: True), in 27.78sec
# iter   7: ll=11099399.595625, converged: 83.18% (loc: 100.00%, scale update: False), in 0.00sec
# iter   8: ll=10931200.182861, converged: 96.64% (loc: 96.64%, scale update: True), in 15.12sec
# iter   9: ll=10931200.182861, converged: 96.64% (loc: 100.00%, scale update: False), in 0.00sec
# ...

# %%
formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata_d30.copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['DB_early_proliferation']) ) ]

adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Condition'] == 'PIMQ']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_PIMQ_vs_Control_DB_early_proliferation_timepoint_D30.csv')


formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata_y1.copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['DB_early_proliferation']) ) ]

adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Condition'] == 'PIMQ']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_PIMQ_vs_Control_DB_early_proliferation_timepoint_Y1.csv')


formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata_d30.copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['DB_intermediate']) ) ]

adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Condition'] == 'PIMQ']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_PIMQ_vs_Control_DB_intermediate_timepoint_D30.csv')


formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata_y1.copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['DB_intermediate']) ) ]

adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Condition'] == 'PIMQ']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_PIMQ_vs_Control_DB_intermediate_timepoint_Y1.csv')




formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata_d30.copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['DB_stress']) ) ]

adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Condition'] == 'PIMQ']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_PIMQ_vs_Control_DB_stress_timepoint_D30.csv')


formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata_y1.copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['DB_stress']) ) ]

adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Condition'] == 'PIMQ']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_PIMQ_vs_Control_DB_stress_timepoint_Y1.csv')



formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata_d30.copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['DB_advanced']) ) ]

adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Condition'] == 'PIMQ']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_PIMQ_vs_Control_DB_advanced_timepoint_D30.csv')


formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata_y1.copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['DB_advanced']) ) ]

adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Condition'] == 'PIMQ']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_PIMQ_vs_Control_DB_advanced_timepoint_Y1.csv')



formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata_d30.copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['UB_proliferation']) ) ]

adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Condition'] == 'PIMQ']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_PIMQ_vs_Control_UB_proliferation_timepoint_D30.csv')


formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata_y1.copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['UB_proliferation']) ) ]

adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Condition'] == 'PIMQ']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_PIMQ_vs_Control_UB_proliferation_timepoint_Y1.csv')


formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata_d30.copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['UB_structure']) ) ]

adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Condition'] == 'PIMQ']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_PIMQ_vs_Control_UB_structure_timepoint_D30.csv')


formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata_y1.copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['UB_structure']) ) ]

adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Condition'] == 'PIMQ']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_PIMQ_vs_Control_UB_structure_timepoint_Y1.csv')




formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata_d30.copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['UB_stem_like']) ) ]

adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Condition'] == 'PIMQ']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_PIMQ_vs_Control_UB_stem_like_timepoint_D30.csv')


formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata_y1.copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['UB_stem_like']) ) ]

adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Condition'] == 'PIMQ']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_PIMQ_vs_Control_UB_stem_like_timepoint_Y1.csv')



formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata_d30.copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['UB_classic']) ) ]

adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Condition'] == 'PIMQ']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_PIMQ_vs_Control_UB_classic_timepoint_D30.csv')


formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata_y1.copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['UB_classic']) ) ]

adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Condition'] == 'PIMQ']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_PIMQ_vs_Control_UB_classic_timepoint_Y1.csv')


formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata_d30.copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['uHFSC']) ) ]

adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Condition'] == 'PIMQ']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_PIMQ_vs_Control_uHFSC_timepoint_D30.csv')


formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata_y1.copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['uHFSC']) ) ]

adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Condition'] == 'PIMQ']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_PIMQ_vs_Control_uHFSC_timepoint_Y1.csv')
# Out:
# /tmp/ipykernel_317372/1611853324.py:8: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Condition'] == 'PIMQ']
# training location model: False
# training scale model: True
# iter   0: ll=30616092.103525
# iter   1: ll=30616092.103525, converged: 0.00% (loc: 100.00%, scale update: False), in 0.00sec
# iter   2: ll=419101.539235, converged: 0.00% (loc: 0.00%, scale update: True), in 4.25sec
# iter   3: ll=419101.539235, converged: 0.00% (loc: 100.00%, scale update: False), in 0.00sec
# iter   4: ll=172420.281243, converged: 44.64% (loc: 44.64%, scale update: True), in 3.89sec
# iter   5: ll=172420.281243, converged: 44.64% (loc: 100.00%, scale update: False), in 0.00sec
# iter   6: ll=160657.392546, converged: 82.60% (loc: 82.60%, scale update: True), in 2.27sec
# ...

# %%
formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata[adata.obs['Condition'] == 'Control'].copy()
adata_sub.X = adata_sub.X.toarray()

adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Time'] == 'D30']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_control_D30_vs_Y1_all_data.csv')

formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata[adata.obs['Condition'] == 'Control'].copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['DB_early_proliferation', 'DB_intermediate', 'DB_stress', 'DB_advanced']) ) ]
adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Time'] == 'D30']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_control_D30_vs_Y1_DB.csv')

formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata[adata.obs['Condition'] == 'Control'].copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['UB_proliferation', 'UB_structure', 'UB_stem_like', 'UB_classic']) ) ]
adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Time'] == 'D30']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_control_D30_vs_Y1_UB.csv')



formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata[adata.obs['Condition'] == 'Control'].copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['UB_proliferation', 'UB_structure', 'UB_stem_like', 'UB_classic', 'uHFSC'])) ]
adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Time'] == 'D30']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_control_D30_vs_Y1_Full_UB.csv')
# Out:
# training location model: False
# training scale model: True
# iter   0: ll=1342614899.111532
# iter   1: ll=1342614899.111532, converged: 0.00% (loc: 100.00%, scale update: False), in 0.00sec
# iter   2: ll=11506022.463085, converged: 0.00% (loc: 0.00%, scale update: True), in 40.13sec
# iter   3: ll=11506022.463085, converged: 0.00% (loc: 100.00%, scale update: False), in 0.00sec
# iter   4: ll=9597683.161953, converged: 43.82% (loc: 43.82%, scale update: True), in 37.61sec
# iter   5: ll=9597683.161953, converged: 43.82% (loc: 100.00%, scale update: False), in 0.00sec
# iter   6: ll=9019664.021537, converged: 83.40% (loc: 83.40%, scale update: True), in 24.25sec
# iter   7: ll=9019664.021537, converged: 83.40% (loc: 100.00%, scale update: False), in 0.00sec
# iter   8: ll=8852967.283211, converged: 96.44% (loc: 96.44%, scale update: True), in 12.01sec
# iter   9: ll=8852967.283211, converged: 96.44% (loc: 100.00%, scale update: False), in 0.00sec
# ...

# %%
formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata[adata.obs['Condition'] == 'PIMQ'].copy()
adata_sub.X = adata_sub.X.toarray()

adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Time'] == 'D30']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_PIMQ_D30_vs_Y1_all_data.csv')

formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata[adata.obs['Condition'] == 'PIMQ'].copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['DB_early_proliferation', 'DB_intermediate', 'DB_stress', 'DB_advanced']) ) ]
adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Time'] == 'D30']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_PIMQ_D30_vs_Y1_DB.csv')

formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata[adata.obs['Condition'] == 'PIMQ'].copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['UB_proliferation', 'UB_structure', 'UB_stem_like', 'UB_classic']) ) ]
adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Time'] == 'D30']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_PIMQ_D30_vs_Y1_UB.csv')



formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata[adata.obs['Condition'] == 'PIMQ'].copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['UB_proliferation', 'UB_structure', 'UB_stem_like', 'UB_classic', 'uHFSC'])) ]
adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Time'] == 'D30']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_PIMQ_D30_vs_Y1_Full_UB.csv')
# Out:
# training location model: False
# training scale model: True
# iter   0: ll=1279473353.477406
# iter   1: ll=1279473353.477406, converged: 0.00% (loc: 100.00%, scale update: False), in 0.00sec
# iter   2: ll=10617524.037580, converged: 0.00% (loc: 0.00%, scale update: True), in 37.50sec
# iter   3: ll=10617524.037580, converged: 0.00% (loc: 100.00%, scale update: False), in 0.00sec
# iter   4: ll=8975944.892525, converged: 44.36% (loc: 44.36%, scale update: True), in 34.48sec
# iter   5: ll=8975944.892525, converged: 44.36% (loc: 100.00%, scale update: False), in 0.00sec
# iter   6: ll=8433529.005816, converged: 82.69% (loc: 82.69%, scale update: True), in 22.43sec
# iter   7: ll=8433529.005816, converged: 82.69% (loc: 100.00%, scale update: False), in 0.00sec
# iter   8: ll=8298595.145149, converged: 96.29% (loc: 96.29%, scale update: True), in 9.73sec
# iter   9: ll=8298595.145149, converged: 96.29% (loc: 100.00%, scale update: False), in 0.00sec
# ...

# %%
formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata.copy()
adata_sub.X = adata_sub.X.toarray()

adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Time'] == 'D30']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_D30_vs_Y1_all_data.csv')

formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata.copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['DB_early_proliferation', 'DB_intermediate', 'DB_stress', 'DB_advanced']) ) ]
adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Time'] == 'D30']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_D30_vs_Y1_DB.csv')

formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata.copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['UB_proliferation', 'UB_structure', 'UB_stem_like', 'UB_classic']) ) ]
adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Time'] == 'D30']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_D30_vs_Y1_UB.csv')



formula = "~1 + factor_to_test"
min_cells = 10

adata_sub = adata.copy()
adata_sub.X = adata_sub.X.toarray()
adata_sub = adata_sub[ (adata_sub.obs['celltype'].isin(['UB_proliferation', 'UB_structure', 'UB_stem_like', 'UB_classic', 'uHFSC'])) ]
adata_sub.obs['factor_to_test'] = ['G1' if x else 'G2' for x in adata_sub.obs['Time'] == 'D30']
adata_sub = adata_sub[:, (adata_sub.X > 0).sum(axis=0) > min_cells]
test = de.test.wald(data = adata_sub, formula_loc = formula, factor_loc_totest = 'factor_to_test', coef_to_test = 'G1')
test.summary().to_csv('../intermediate_outputs/strict_diffxpy/diffxpy_D30_vs_Y1_Full_UB.csv')
# Out:
# /mnt/c/Users/sotougl/Software/batchglm/batchglm/models/base_glm/utils.py:158: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   np.mean(x[np.where(grouping == g)[0], :], axis=0)
# /mnt/c/Users/sotougl/Software/batchglm/batchglm/models/base_glm/utils.py:171: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
# ...
